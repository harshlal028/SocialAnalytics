# %%
import pickle
import json
import numpy as np
import pandas as pd
import math

from bokeh.plotting import figure, show, output_notebook
from bokeh.tile_providers import CARTODBPOSITRON

# %%
def fix_JSON(json_message=None):
    '''This function fixes errors in the JSON if any and return a json dictionary'''
    result = None
    try:        
        result = json.loads(json_message)
    except Exception as e:      
        # Find the offending character index:
        e_message = str(e)
        idx_to_replace = int(e_message.split(' ')[-1].replace(')',''))   
        
        #print(e_message,idx_to_replace)
        # Remove the offending character:
        json_message = list(json_message)
        json_message[idx_to_replace] = ' '
        new_message = ''.join(json_message)     
        return fix_JSON(json_message=new_message)
    return result

# %%
def get_lat_long(bbox):
    bbox = bbox['coordinates']
    try:
        bb = np.array(bbox[0])
        lat = np.average(bb[:,0])
        lon = np.average(bb[:,1])
    except:
        lat,lon = None,None
    return lon,lat

# %%
def get_x(f):
    def g(*args):
        rv = f(*args)
        return rv[0]
    return g

def get_y(f):
    def g(*args):
        rv = f(*args)
        return rv[1]
    return g

# %%
@get_y
def merc(row):
    lat = row['lat']
    lon = row['lon']
    if lat is None or lon is None:
        return (0,0)
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + lat * (math.pi/180.0)/2.0)) * scale
    return (x, y)

# %% [markdown]
# ## Processinf file : neighborhoods.json

# %%
BASE_PATH = 'E:\Datasets\TWITTER_SOCG\CONTROL\%s'
file_name = 'neighborhoods.json'
file = BASE_PATH%(file_name)

# %%
neigh = []

# %%
with open(file) as f:
    for line in f:
        tmp_all = fix_JSON(line)
        lat,lon = get_lat_long(tmp_all.get('bounding_box',None))
        tmp_all['lat'] = lat
        tmp_all['lon'] = lon
        neigh.append(tmp_all)

# %%
df = pd.DataFrame.from_records(neigh)

# %%
df.columns
# Out:
# Index(['attributes', 'bounding_box', 'contained_within', 'country',
#        'country_code', 'full_name', 'id', 'lat', 'lon', 'name', 'place_type',
#        'url'],
#       dtype='object')

# %%
df['coord_x'] = df.apply (lambda row: merc(row),axis=1) ## Toggle decorator

# %%
df['coord_y'] = df.apply (lambda row: merc(row),axis=1) ## Toggle decorator

# %%
df.head()
# Out:
#   attributes                                       bounding_box  \
# 0         {}  {'type': 'Polygon', 'coordinates': [[[-122.406...
# 1         {}  {'type': 'Polygon', 'coordinates': [[[-73.9126...
# 2         {}  {'type': 'Polygon', 'coordinates': [[[-84.4049...
# 3         {}  {'type': 'Polygon', 'coordinates': [[[-122.414...
# 4         {}  {'type': 'Polygon', 'coordinates': [[[-73.9386...
#
#   contained_within        country country_code  \
# 0               []  United States           US
# 1               []  United States           US
# 2               []  United States           US
# 3               []  United States           US
# 4               []  United States           US
#
#                         full_name                id        lat         lon  \
# 0  The Embarcadero, San Francisco  90942366be65cd2c  37.792149 -122.395603
# 1         Jackson Heights, Queens  183671f841b462d5  40.756939  -73.896411
# 2       Lakewood Heights, Atlanta  4cab0cff30803a20  33.705999  -84.385970
# 3        Chinatown, San Francisco  e181b00c2f52bb2d  37.797589 -122.408835
# 4          Fort George, Manhattan  255794afe77688b1  40.856943  -73.928499
#
#                name    place_type  \
# 0   The Embarcadero  neighborhood
# 1   Jackson Heights  neighborhood
# 2  Lakewood Heights  neighborhood
# 3         Chinatown  neighborhood
# 4       Fort George  neighborhood
#
#                                                  url       coord_x  \
# 0  https://api.twitter.com/1.1/geo/id/90942366be6... -1.362502e+07
# 1  https://api.twitter.com/1.1/geo/id/183671f841b... -8.226111e+06
# 2  https://api.twitter.com/1.1/geo/id/4cab0cff308... -9.393803e+06
# 3  https://api.twitter.com/1.1/geo/id/e181b00c2f5... -1.362649e+07
# 4  https://api.twitter.com/1.1/geo/id/255794afe77... -8.229683e+06
#
#         coord_y
# 0  4.550105e+06
# 1  4.976556e+06
# 2  3.989393e+06
# 3  4.550871e+06
# 4  4.991264e+06

# %%
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)
p.circle(x = df['coord_x'], 
         y = df['coord_y'],
         size=10,
         line_color="#FF0000", 
         fill_color="#FF0000",
         fill_alpha=0.05)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1051">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4272eb4c-8211-4d72-9946-167c7c0fe931" data-root-id="1002"></div>

# %% [markdown]
# ## Processing file : points.json

# %%
file_name = 'points.json'
file = BASE_PATH%(file_name)

# %%
points = []

# %%
with open(file) as f:
    for line in f:
        tmp_all = fix_JSON(line)
        lat,lon = get_lat_long(tmp_all.get('bounding_box',None))
        tmp_all['lat'] = lat
        tmp_all['lon'] = lon
        points.append(tmp_all)

# %%
df1 = pd.DataFrame.from_records(points)

# %%
df1.columns
# Out:
# Index(['attributes', 'bounding_box', 'contained_within', 'country',
#        'country_code', 'full_name', 'id', 'lat', 'lon', 'name', 'place_type',
#        'url'],
#       dtype='object')

# %%
df1['coord_x'] = df.apply (lambda row: merc(row),axis=1) ## Toggle decorator

# %%
df1['coord_y'] = df.apply (lambda row: merc(row),axis=1) ## Toggle decorator

# %%
df1.head()
# Out:
#   attributes                                       bounding_box  \
# 0         {}  {'type': 'Polygon', 'coordinates': [[[-93.2362...
# 1         {}  {'type': 'Polygon', 'coordinates': [[[-112.083...
# 2         {}  {'type': 'Polygon', 'coordinates': [[[-111.739...
# 3         {}  {'type': 'Polygon', 'coordinates': [[[-85.3361...
# 4         {}  {'type': 'Polygon', 'coordinates': [[[-72.9171...
#
#   contained_within        country country_code                full_name  \
# 0               []  United States           US  Loring Bar & Restaurant
# 1               []  United States           US   Unexpected Art Gallery
# 2               []  United States           US           Raising Cane's
# 3               []  United States           US          The Field House
# 4               []  United States           US       Canton High School
#
#                  id        lat         lon                     name  \
# 0  0ce294aa05d79000  44.980420  -93.236250  Loring Bar & Restaurant
# 1  091ec127c9d72001  33.453708 -112.083795   Unexpected Art Gallery
# 2  0c2ed9b30156b000  33.381074 -111.739979           Raising Cane's
# 3  07d9f459fa887002  35.086167  -85.336188          The Field House
# 4  07d9ee7ad3c80001  41.825261  -72.917181       Canton High School
#
#   place_type                                                url       coord_x  \
# 0        poi  https://api.twitter.com/1.1/geo/id/0ce294aa05d... -1.362502e+07
# 1        poi  https://api.twitter.com/1.1/geo/id/091ec127c9d... -8.226111e+06
# 2        poi  https://api.twitter.com/1.1/geo/id/0c2ed9b3015... -9.393803e+06
# 3        poi  https://api.twitter.com/1.1/geo/id/07d9f459fa8... -1.362649e+07
# 4        poi  https://api.twitter.com/1.1/geo/id/07d9ee7ad3c... -8.229683e+06
#
#         coord_y
# 0  4.550105e+06
# 1  4.976556e+06
# 2  3.989393e+06
# 3  4.550871e+06
# 4  4.991264e+06

# %%
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)
p.circle(x = df1['coord_x'], 
         y = df1['coord_y'],
         size=10,
         line_color="#FF0000", 
         fill_color="#FF0000",
         fill_alpha=0.05)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1417">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b473238c-ee1c-4e1d-8054-d3e634c716e8" data-root-id="1368"></div>
